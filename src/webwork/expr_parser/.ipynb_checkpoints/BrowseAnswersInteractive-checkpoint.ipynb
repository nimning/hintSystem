# %%
import requests
import pandas as pd
import numpy as np
from IPython.html.widgets import interact, interactive, fixed
from IPython.html import widgets
from IPython.display import clear_output, display, HTML
from collections import OrderedDict

# %%
# Load all course data
url = 'http://webwork.cse.ucsd.edu:4351/answers_by_part'
course='UCSD_CSE103'
r = requests.get(url, params={'course':course})
data=r.json()
DF = pd.DataFrame(data)

# %%
# Create dropdowns
s=DF.groupby('set_id').size()
s.sort(ascending=False)
sets = OrderedDict([("{0} - {1}".format(k,v), k) for k,v in s.iteritems()])

assignment_picker = widgets.DropdownWidget(values=sets, description="Assignment:")
problem_picker = widgets.DropdownWidget(values=[], description="Problem")
part_picker = widgets.DropdownWidget(values=[], description="Part")
user_picker = widgets.DropdownWidget(values=[], description="User")

# Defaults
assignment = sets.values()[0]
problem = 0
part = 0
user=""
data = DF

# Change listeners
def on_assignment_change(trait_name, new_value):
    global assignment
    assignment = new_value
    update_problems()
    update_users()
    refilter()
    
def on_problem_change(trait_name, new_value):
    global problem
    problem = new_value
    update_parts()
    update_users()
    refilter()

def on_part_change(trait_name, new_value):
    global part
    part = new_value
    update_users()
    refilter()
    
def on_user_change(trait_name, new_value):
    global user
    user = new_value
    refilter()

def update_problems():
    problems = DF[DF['set_id']==assignment].groupby('problem_id').size()
    problems.sort_index()
    problem_picker.values = OrderedDict([("{0} - {1}".format(k,v),k) for k,v in problems.iteritems()])
    
def update_parts():
    parts = DF[(DF['set_id']==assignment) & (DF['problem_id']==problem)].groupby('part_id').size()
    parts.sort_index()
    part_picker.values = OrderedDict([("{0} - {1}".format(k,v),k) for k,v in parts.iteritems()])
    
def update_users():
    global user
    user=""
    user_counts = DF[(DF['set_id']==assignment) & (DF['problem_id']==problem) & (DF['part_id']==part)].groupby('user_id').size()
    user_counts.sort(ascending=False)
    user_picker.values = OrderedDict([("{0} - {1}".format(k,v), k) for k,v in user_counts.iteritems()])

def refilter():
    global data
    data = DF[(DF['set_id']==assignment) & (DF['problem_id']==problem) & (DF['part_id']==part) & (DF['user_id'].str.startswith(user))]
    
assignment_picker.on_trait_change(on_assignment_change, 'value')
problem_picker.on_trait_change(on_problem_change, 'value')
part_picker.on_trait_change(on_part_change, 'value')
user_picker.on_trait_change(on_user_change, 'value')

# %%
display(assignment_picker)
display(problem_picker)
display(part_picker)
display(user_picker)

# %%
data.sort('timestamp')
# Out:
#         answer_id                                      answer_string     id  \
# 100255      62028                                             13^4*3  30497
# 100257      62030                                            13^4*12  30498
# 100259      62032                                     52*51*50*49*12  30499
# 100263      62036                                    C(52,4)*C(12,1)  30500
# 100270      62043                                    C(52,5)-C(40,5)  30501
# 100288      62055                                    C(52,5)-C(34,5)  30502
# 100291      62057                                    C(52,5)-C(30,5)  30504
# 100292      62058                          (C(52,5)-C(40,5))-C(30,5)  30505
# 100296      62060                          (C(52,5)-C(40,5))-C(34,5)  30506
# 100305      62067                                             (28,5)  30507
# 100306      62068                                            C(28,5)  30508
# 100313      62073                                    C(28,4)*C(12,1)  30509
# 100345      62092                (C(52,5)-C(40,5))-(C(52,5)-C(34,5))  30510
# 100361      62105                        (C(52,5)-C(40,5))-(C(18,5))  30511
# 100362      62106                        (C(52,5)-C(40,5))-(C(34,5))  30512
# 100420      62150                                  (C(52,5)-C(24,5))  30513
# 100426      62153                (C(52,5)-C(24,5))-(C(52,5)-C(40,5))  30514
# 100433      62160                                            C(24,5)  30515
# 100434      62161                                    C(52,5)-C(24,5)  30516
# 100437      62164                            C(52,5)-C(40,5)-C(24,5)  30517
# 100444      62170                           (C(52,5)-C(40,5))-(28,5)  30518
# 100445      62171                          (C(52,5)-C(40,5))-C(28,5)  30519
# 100469      62192                                  (C(52,5)-C(34,5))  30520
# 100499      62220                                  (C(52,5)-C(32,5))  30521
# 100504      62225                (C(52,5)-C(32,5))-(C(52,5)-C(40,5))  30522
# 100556      62260                            C(52,5)-C(40,5)-C(20,5)  30523
# 100659      62323                         C(52,5)-C(40,5)-(C(52,28))  30524
# 100710      62361                  C(52,5)-C(40,5)-(C(52,5)-C(20,5))  30525
# 100714      62365                  C(52,5)-C(40,5)-(C(52,5)-C(32,5))  30526
# 100891      62509  C(52,5)-(C(52,5)-(C(52,5)-C(40,5)))-(C(52,5)-C...  30527
# 100896      62513                          C(52,5)-(C(52,5)-C(40,5))  30528
# 100898      62515                  C(52,5)-(C(52,5)-C(40,5))-C(32,5)  30529
# 100911      62523  C(52,5)-C(52,5)-(C(52,5)-C(40,5))-(C(52,5)-C(3...  30530
# 100912      62524        C(52,5)-(C(52,5)-C(40,5))-(C(52,5)-C(32,5))  30531
# 100913      62525        C(52,5)-(C(52,5)-C(40,5))-(C(52,5)-C(20,5))  30532
# 100917      62528                          C(52,5)-(C(52,5)-C(40,5))  30533
# 100939      62547                                    C(52,5)-C(40,5)  30535
# 101026      62588                          C(52,5)-(C(52,5)-C(40,5))  30538
# 101040      62594                                    C(40,5)-C(32,5)  30540
# 101041      62595                                    C(40,5)-C(28,5)  30541
# 101043      62597                                    C(40,5)-C(20,5)  30542
# 101057      62605                            C(52,5)-C(40,5)-C(32,5)  30543
# 101062      62608                            C(52,5)-C(40,5)-C(28,5)  30544
# 101125      62643                                    C(32,5)-C(40,5)  30545
# 101133      62648                                    C(28,5)-C(40,5)  30546
# 101136      62651                                     C(40,5)-(32,5)  30547
# 101137      62652                                    C(40,5)-C(32,5)  30548
# 101153      62664                                    C(20,5)-C(40,5)  30549
# 101184      62684                                              15504  30550
# 101207      62698                            ((52,5)-(32,5))-C(40,5)  30551
# 101208      62699                          (C(52,5)-C(32,5))-C(40,5)  30552
# 101249      62719                  C(52,5)-(C(52,5)-C(32,5))-C(40,5)  30553
# 101255      62722                (C(52,5)-(C(52,5)-C(32,5)))-C(40,5)  30554
# 101263      62725                          (C(52,5)-C(32,5))-C(40,5)  30555
# 101345      62755                           (52C5) - (32C5) - (20C5)  30556
# 101346      62756                        C(52,5) - C(32,5) - C(20,5)  30557
# 102034      63255                                    C(32,5)-C(20,5)  30558
#
#         part_id  problem_id score              set_id            timestamp  \
# 101133        0           1     0  Assignment10.16.13  2013-10-17T22:55:15
# 101136        0           1     0  Assignment10.16.13  2013-10-17T22:55:51
# 101137        0           1     0  Assignment10.16.13  2013-10-17T22:55:58
# 101153        0           1     0  Assignment10.16.13  2013-10-17T22:58:11
# 101184        0           1     0  Assignment10.16.13  2013-10-17T23:01:40
# 101207        0           1     0  Assignment10.16.13  2013-10-17T23:03:42
# 101208        0           1     0  Assignment10.16.13  2013-10-17T23:03:52
# 101249        0           1     0  Assignment10.16.13  2013-10-17T23:09:44
# 101255        0           1     0  Assignment10.16.13  2013-10-17T23:10:08
# 101263        0           1     0  Assignment10.16.13  2013-10-17T23:11:21
# 101345        0           1     0  Assignment10.16.13  2013-10-17T23:20:26
# 101346        0           1     0  Assignment10.16.13  2013-10-17T23:21:05
# 102034        0           1     1  Assignment10.16.13  2013-10-18T01:15:54
#
#         user_id
# 100255  khchong
# 100257  khchong
# 100259  khchong
# 100263  khchong
# 100270  khchong
# 100288  khchong
# 100291  khchong
# 100292  khchong
# 100296  khchong
# 100305  khchong
# 100306  khchong
# 100313  khchong
# 100345  khchong
# 100361  khchong
# 100362  khchong
# 100420  khchong
# 100426  khchong
# 100433  khchong
# 100434  khchong
# 100437  khchong
# 100444  khchong
# 100445  khchong
# 100469  khchong
# 100499  khchong
# 100504  khchong
# 100556  khchong
# 100659  khchong
# 100710  khchong
# 100714  khchong
# 100891  khchong
# 100896  khchong
# 100898  khchong
# 100911  khchong
# 100912  khchong
# 100913  khchong
# 100917  khchong
# 100939  khchong
# 101026  khchong
# 101040  khchong
# 101041  khchong
# 101043  khchong
# 101057  khchong
# 101062  khchong
# 101125  khchong
# 101133  khchong
# 101136  khchong
# 101137  khchong
# 101153  khchong
# 101184  khchong
# 101207  khchong
# 101208  khchong
# 101249  khchong
# 101255  khchong
# 101263  khchong
# 101345  khchong
# 101346  khchong
# 102034  khchong

# %% [raw]
# Problem 10.16.13/1
# BEGIN_PGML
#
# *Find the probability that a poker hand of 5 cards from a standard deck will contain no card smaller than 7 (i.e. 2,3...6) (call this event [`A`]), given that it contains at least one face card (i.e. J, Q, K) (call this event [`B`])"?*
#
# We define two events:
# * Event [`A`]: The hand contains no card smaller than 7.
# * Event [`B`]: The hand contains at least one face card.
#
# We start by computing the size of the relevant events
#     - Which ranks can be used in the hands defined by ['A']? [___________________]{Set('7','8','9','10','J','Q','K','A')}
#     - [`|A|` =][____________]{Compute("C(32,5)")
#     - Which ranks can be used in the complement of ['B']? [___________________]{Set('2','3','4','5','6','7','8','9','10','A')}
#     - What is the size of the complement of ['B']? [____________]{C(40,5)}
#     - [`|B| = `] [____________]{Compute("C(52,5)-C(40,5)")}
#     - [`|A \cap B| = `] [____________]{Compute("C(32,5)-C(20,5)")}
#
# We then use the ratio between the sizes of the events to find the conditional probability:
#     - The conditional probability [`P(A|B) = `] [____________]{Compute("(C(32,5)-C(20,5))/(C(52,5)-C(40,5))")}
#
# END_PGML
