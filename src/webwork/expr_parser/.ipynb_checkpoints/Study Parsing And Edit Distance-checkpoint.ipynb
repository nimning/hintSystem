# %%
# %pwd
# Out:
# u'/Users/yoavfreund/projects/Webwork.Improvement.Project/AdaptiveHints/src/webwork/expr_parser'

# %%
"""
3) Necessary imports:
"""
# !rm parser.out
import webwork_parser
reload(webwork_parser)
import Eval_parsed
reload(Eval_parsed)
import pandas as pd
import numpy as np
import json
from zss import simple_distance
#from k_medoids_clustering import ExpressionNode
### Right now import immediately executes clustering. Make import just be an import.
# Out:
# rm: parser.out: No such file or directory
# setting up logging

# %%
# %pdb off
string='C(32,5)- C(20,5)'
#string='(1+2)*(3+4)'
#string='C(32,5)'
A=webwork_parser.parse_webwork(string)
print A
# Out:
# Automatic pdb calling has been turned OFF
# (('-', (0, 15)), (('C', (0, 6)), 32, 5), (('C', (9, 15)), 20, 5))

# %%
A
# Out:
# (('-', (0, 15)), (('C', (0, 6)), 32, 5), (('C', (9, 15)), 20, 5))

# %%
etree=Eval_parsed.eval_parsed(A)
etree
# Out:
# (('-', 185872L, (0, 15)),
#  (('C', 201376L, (0, 6)), (32.0,), (5.0,)),
#  (('C', 15504, (9, 15)), (20.0,), (5.0,)))

# %%
Eval_parsed.Collect_numbers(etree)
# Out:
# {5.0: (5.0,),
#  20.0: (20.0,),
#  32.0: (32.0,),
#  15504: (('C', 15504, (9, 15)), (20.0,), (5.0,)),
#  185872L: (('-', 185872L, (0, 15)),
#   (('C', 201376L, (0, 6)), (32.0,), (5.0,)),
#   (('C', 15504, (9, 15)), (20.0,), (5.0,))),
#  201376L: (('C', 201376L, (0, 6)), (32.0,), (5.0,))}

# %%
tries=pd.read_json('example_struggle.json')
tries.groupby('user_id').count()
# Out:
#           answer_id  answer_string  id  part_id  problem_id  score  set_id  \
# user_id
# a4to              3              3   3        3           3      3       3
# a5taylor          2              2   2        2           2      2       2
# a7luong          17             17  17       17          17     17      17
# abw004            2              2   2        2           2      2       2
# actsang           7              7   7        7           7      7       7
# adfisher          6              6   6        6           6      6       6
# aferbrac         16             16  16       16          16     16      16
# ajjiang           7              7   7        7           7      7       7
# ajudah           17             17  17       17          17     17      17
# akhosla           5              5   5        5           5      5       5
# alt020           10             10  10       10          10     10      10
# altam            13             13  13       13          13     13      13
# anarsian          4              4   4        4           4      4       4
# aplin            14             14  14       14          14     14      14
# apmodi            2              2   2        2           2      2       2
# ascherme          3              3   3        3           3      3       3
# aschilli          2              2   2        2           2      2       2
# asraman          15             15  15       15          15     15      15
# atjaiswa          6              6   6        6           6      6       6
# avaradha         40             40  40       40          40     40      40
# awchar           13             13  13       13          13     13      13
# ayl051            7              7   7        7           7      7       7
# b7chung          13             13  13       13          13     13      13
# babney            7              7   7        7           7      7       7
# bbarmeye          8              8   8        8           8      8       8
# bbatenga          2              2   2        2           2      2       2
# bbatra           12             12  12       12          12     12      12
# bcrussel          1              1   1        1           1      1       1
# bhc002            1              1   1        1           1      1       1
# blcollin         20             20  20       20          20     20      20
# ...             ...            ...  ..      ...         ...    ...     ...
# ssampang          4              4   4        4           4      4       4
# ssko             10             10  10       10          10     10      10
# ssoni             2              2   2        2           2      2       2
# suliu            19             19  19       19          19     19      19
# t10lee            2              2   2        2           2      2       2
# tcampbel          1              1   1        1           1      1       1
# tgtruong          9              9   9        9           9      9       9
# thvo              4              4   4        4           4      4       4
# tiw005            3              3   3        3           3      3       3
# tiz012            8              8   8        8           8      8       8
# tochiai          17             17  17       17          17     17      17
# trtucker          1              1   1        1           1      1       1
# twc006            6              6   6        6           6      6       6
# tyxie            20             20  20       20          20     20      20
# valeong           8              8   8        8           8      8       8
# vivenkat          4              4   4        4           4      4       4
# w1love            9              9   9        9           9      9       9
# whyao             1              1   1        1           1      1       1
# wihuang           3              3   3        3           3      3       3
# x9xu              3              3   3        3           3      3       3
# xil039            3              3   3        3           3      3       3
# xiwen            10             10  10       10          10     10      10
# xiz082            7              7   7        7           7      7       7
# yiahmed          12             12  12       12          12     12      12
# ylemberg          6              6   6        6           6      6       6
# yochang          15             15  15       15          15     15      15
# yuncong           3              3   3        3           3      3       3
# yuz222            4              4   4        4           4      4       4
# z3zeng            4              4   4        4           4      4       4
# zowu              1              1   1        1           1      1       1
#
#           timestamp
# user_id
# a4to              3
# a5taylor          2
# a7luong          17
# abw004            2
# actsang           7
# adfisher          6
# aferbrac         16
# ajjiang           7
# ajudah           17
# akhosla           5
# alt020           10
# altam            13
# anarsian          4
# aplin            14
# apmodi            2
# ascherme          3
# aschilli          2
# asraman          15
# atjaiswa          6
# avaradha         40
# awchar           13
# ayl051            7
# b7chung          13
# babney            7
# bbarmeye          8
# bbatenga          2
# bbatra           12
# bcrussel          1
# bhc002            1
# blcollin         20
# ...             ...
# ssampang          4
# ssko             10
# ssoni             2
# suliu            19
# t10lee            2
# tcampbel          1
# tgtruong          9
# thvo              4
# tiw005            3
# tiz012            8
# tochiai          17
# trtucker          1
# twc006            6
# tyxie            20
# valeong           8
# vivenkat          4
# w1love            9
# whyao             1
# wihuang           3
# x9xu              3
# xil039            3
# xiwen            10
# xiz082            7
# yiahmed          12
# ylemberg          6
# yochang          15
# yuncong           3
# yuz222            4
# z3zeng            4
# zowu              1
#
# [180 rows x 8 columns]

# %%
users=list(set(tries['user_id']))

# %%
attempts={}
j=0;
for user in users:
    answers=tries[tries['user_id']==user]['answer_string']
    print user,len(answers),
    attempts[user]=extract_attempt_trajectory(answers,HG)
    print len(attempts[user])
    j+=1; 
    if j>40: break
# Out:
# ERROR:root:Error  : factor DIVIDE LPAREN factor . $end
# jwk020 8 i= 5 1/((C(12,1)+C(40,4)) Syntax error
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# To exit: use 'exit', 'quit', or Ctrl-D.

# %%
import sys
def extract_attempt_trajectory(answers,HG):
    attempts=[]
    i=0
    for answer in answers:
        i+=1
        try:
            #print 'Attempt text="%s"'%answer,
            ptree = webwork_parser.parse_webwork(answer)
            etree=Eval_parsed.eval_parsed(ptree)
            H=Eval_parsed.Collect_numbers(etree)
            common=sort(list((set(H.keys()) & HG)))
            not_in_correct = sort(list((set(H.keys()) - HG)))
            #print '\t', '['+','.join(['%2.0f'%v for v in common])+']',
            #print '\t', '['+','.join(['%2.0f'%v for v in not_in_correct])+']'
            attempts.append((answer,common,not_in_correct))
        except Exception, e:
            print 'i=',i, answer,e
            sys.exit()
    return attempts

# %%
for user in users:
    print shape(tries[tries['user_id']==user]['answer_string'])
    print attempts[user]
# Out:
# (8,)
# [(u'C(32,5) - C(20,5)', array([  5.00000000e+00,   2.00000000e+01,   3.20000000e+01,
#          1.55040000e+04,   1.85872000e+05,   2.01376000e+05]), array([], dtype=float64)), (u'C(12,1)+C(40,4)', array([ 4.]), array([  1.00000000e+00,   1.20000000e+01,   4.00000000e+01,
#          9.13900000e+04,   9.14020000e+04])), (u'1/C(12,1)+C(40,4)', array([ 4.]), array([  8.33333333e-02,   1.00000000e+00,   1.20000000e+01,
#          4.00000000e+01,   9.13900000e+04,   9.13900833e+04])), (u'1/(C(12,1)+C(40,4))', array([ 4.]), array([  1.09406796e-05,   1.00000000e+00,   1.20000000e+01,
#          4.00000000e+01,   9.13900000e+04,   9.14020000e+04])), (u'1/((C(12,1)+C(40,4)))', array([ 4.]), array([  1.09406796e-05,   1.00000000e+00,   1.20000000e+01,
#          4.00000000e+01,   9.13900000e+04,   9.14020000e+04]))]
# (9,)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-97-592a471ca71d> in <module>()
#       1 for user in users:
#       2     print shape(tries[tries['user_id']==user]['answer_string'])
# ----> 3     print attempts[user]
#
# KeyError: u'mhogetve'

# %%
hist([len(tries) for tries in attempts],bins=20);

# %%
string='C(4*8,5)- C(4*5,5)'
A=webwork_parser.parse_webwork(string)
print A
# Out:
# (('-', (0, 17)), (('C', (0, 7)), (('*', (2, 4)), 4, 8), 5), (('C', (10, 17)), (('*', (12, 14)), 4, 5), 5))

# %%
etree=Eval_parsed.eval_parsed(A)
print etree
# Out:
# (('-', 185872L, (0, 17)), (('C', 201376L, (0, 7)), (('*', 32.0, (2, 4)), (4.0,), (8.0,)), (5.0,)), (('C', 15504, (10, 17)), (('*', 20.0, (12, 14)), (4.0,), (5.0,)), (5.0,)))

# %%
HS=Eval_parsed.Collect_numbers(etree)
HS
# Out:
# {4.0: (4.0,),
#  5.0: (5.0,),
#  8.0: (8.0,),
#  20.0: (('*', 20.0, (12, 14)), (4.0,), (5.0,)),
#  32.0: (('*', 32.0, (2, 4)), (4.0,), (8.0,)),
#  15504: (('C', 15504, (10, 17)),
#   (('*', 20.0, (12, 14)), (4.0,), (5.0,)),
#   (5.0,)),
#  185872L: (('-', 185872L, (0, 17)),
#   (('C', 201376L, (0, 7)), (('*', 32.0, (2, 4)), (4.0,), (8.0,)), (5.0,)),
#   (('C', 15504, (10, 17)), (('*', 20.0, (12, 14)), (4.0,), (5.0,)), (5.0,))),
#  201376L: (('C', 201376L, (0, 7)),
#   (('*', 32.0, (2, 4)), (4.0,), (8.0,)),
#   (5.0,))}

# %%
HG=set(sort(HS.keys()))
HG
# Out:
# {4.0, 5.0, 8.0, 20.0, 32.0, 15504.0, 185872.0, 201376.0}

# %%
set(H.keys()) - HG
# Out:
# set()

# %%
def is_number(s):
    try:
        float(s)
        return True
    except ValueError:
        return False

# %%
len((float(1),))
# Out:
# 1
