# %%
# %pwd
# Out:
# u'/Users/yoavfreund/projects/Webwork.Improvement.Project/AdaptiveHints/src/webwork/expr_parser'

# %%
"""
3) Necessary imports:
"""
# !rm parser.out
import webwork_parser
reload(webwork_parser)
import Eval_parsed
reload(Eval_parsed)
import pandas as pd
import numpy as np
import json
from zss import simple_distance
#from k_medoids_clustering import ExpressionNode
### Right now import immediately executes clustering. Make import just be an import.
# Out:
# input::: -f
# output::: (('-', (0, 1)), 'f')
# Generating LALR tables
# WARNING: 1 shift/reduce conflict
# WARNING: 13 reduce/reduce conflicts
# WARNING: reduce/reduce conflict in state 48 resolved using rule (expression -> factor MINUS factor)
# WARNING: rejected rule (factor -> MINUS factor) in state 48

# %%
# %pdb off
string='C(32,5)- C(20,5)'
#string='(1+2)*(3+4)'
#string='C(32,5)'
A=webwork_parser.parse_webwork(string)
print A
# Out:
# Automatic pdb calling has been turned OFF
# (('-', (0, 15)), (('C', (0, 6)), 32, 5), (('C', (9, 15)), 20, 5))

# %%
A
# Out:
# (('-', (0, 15)), (('C', (0, 6)), 32, 5), (('C', (9, 15)), 20, 5))

# %%
etree=Eval_parsed.eval_parsed(A)
etree
# Out:
# (('-', 185872L, (0, 15)),
#  (('C', 201376L, (0, 6)), (32.0,), (5.0,)),
#  (('C', 15504, (9, 15)), (20.0,), (5.0,)))

# %%
Eval_parsed.Collect_numbers(etree)
# Out:
# {5.0: (5.0,),
#  20.0: (20.0,),
#  32.0: (32.0,),
#  15504: (('C', 15504, (9, 15)), (20.0,), (5.0,)),
#  185872L: (('-', 185872L, (0, 15)),
#   (('C', 201376L, (0, 6)), (32.0,), (5.0,)),
#   (('C', 15504, (9, 15)), (20.0,), (5.0,))),
#  201376L: (('C', 201376L, (0, 6)), (32.0,), (5.0,))}

# %%
tries=pd.read_csv('example_struggle.csv')
tries
# Out:
#      Unnamed: 0  answer_id                                      answer_string  \
# 0         97175      59875                                            C(47,5)
# 1         97194      59885                                            C(12,5)
# 2         97203      59894                                            C(52,5)
# 3         97209      59898                                 C(52,5) - C(52,36)
# 4         97214      59902                                  C(52,5) - C(36,5)
# 5         97224      59909                                            C(12,1)
# 6         97230      59913                                           C(52,12)
# 7         97248      59929                                  C(52,1) - C(12,1)
# 8         97251      59932                                  C(52,1) - C(40,1)
# 9         97255      59937                                  C(52,1) - C(12,0)
# 10        97268      59946                                  C(12,1) + C(52,4)
# 11        97270      59948                                  C(12,1) + C(40,4)
# 12        97271      59949                                  C(12,1) * C(40,4)
# 13        97273      59951                                  C(12,1) + C(51,4)
# 14        97283      59961                          C(52,5) - C(12,0)*C(52,5)
# 15        97285      59963                          C(12,5) - C(12,0)*C(52,5)
# 16        97294      59969  C(12,1)*C(51,4) + C(12,2)*C(50,3) + C(12,3)*C(...
# 17        97297      59972                                        1 - C(12,0)
# 18        97298      59973                                1 - C(12,0)/C(52,5)
# 19        97300      59975                                1 - C(12,0)/C(12,5)
# 20        97302      59977                                1 - C(12,0)/C(42,5)
# 21        97303      59978                                1 - C(12,0)/C(40,5)
# 22        97305      59980                                  C(52,5) - C(12,0)
# 102  2013-10-17T07:44:14  lahuynh
# 103  2013-10-17T07:45:42  lahuynh
# 104  2013-10-17T07:46:11  lahuynh
# 105  2013-10-17T07:47:01  lahuynh
# 106  2013-10-17T07:47:11  lahuynh
# 107  2013-10-17T08:18:16  lahuynh
# 108  2013-10-17T08:18:27  lahuynh
# 109  2013-10-17T08:19:03  lahuynh
# 110  2013-10-17T08:19:39  lahuynh
# 111  2013-10-17T08:20:12  lahuynh
# 112  2013-10-17T08:20:28  lahuynh
# 113  2013-10-17T08:20:51  lahuynh
# 114  2013-10-17T08:21:28  lahuynh
# 115  2013-10-17T08:21:47  lahuynh
# 116  2013-10-17T08:23:02  lahuynh
# 117  2013-10-17T08:26:54  lahuynh
# 118  2013-10-17T08:27:19  lahuynh
# 119  2013-10-17T08:28:23  lahuynh
# 120  2013-10-17T08:37:05  lahuynh
# 121  2013-10-17T08:37:23  lahuynh
# 122  2013-10-17T08:39:28  lahuynh
# 123  2013-10-17T09:05:05  lahuynh
# 124  2013-10-17T09:10:12  lahuynh
# 125  2013-10-17T09:10:50  lahuynh
# 126  2013-10-17T09:17:42  lahuynh
# 127  2013-10-17T09:17:57  lahuynh
#
# [128 rows x 10 columns]

# %%
answers=tries['answer_string']

# %%
for answer in answers:
    try:
        print 'Attempt text="%s"'%answer,
        ptree = webwork_parser.parse_webwork(answer)
        etree=Eval_parsed.eval_parsed(ptree)
        H=Eval_parsed.Collect_numbers(etree)
        common=list((set(H.keys()) & HG))
        print '\t', '['+','.join(['%2.0f'%v for v in sort(common)])+']'
    except:
        pass
# Out:
# Attempt text="C(47,5)" 	[ 5]
# Attempt text="C(12,5)" 	[ 5]
# Attempt text="C(52,5)" 	[ 5]
# Attempt text="C(52,5) - C(52,36)" 	[ 5]
# Attempt text="C(52,5) - C(36,5)" 	[ 5]
# Attempt text="C(12,1)" 	[]
# Attempt text="C(52,12)" 	[]
# Attempt text="C(52,1) - C(12,1)" 	[]
# Attempt text="C(52,1) - C(40,1)" 	[]
# Attempt text="C(52,1) - C(12,0)" 	[]
# Attempt text="C(12,1) + C(52,4)" 	[ 4]
# Attempt text="C(12,1) + C(40,4)" 	[ 4]
# Attempt text="C(12,1) * C(40,4)" 	[ 4]
# Attempt text="C(12,1) + C(51,4)" 	[ 4]
# Attempt text="C(52,5) - C(12,0)*C(52,5)" 	[ 5]
# Attempt text="C(12,5) - C(12,0)*C(52,5)" 	[ 5]
# Attempt text="C(12,1)*C(51,4) + C(12,2)*C(50,3) + C(12,3)*C(49,2) + C(12,4)*C(48,1) + C(12,5)*C(47,0)" 	[ 4, 5]
# Attempt text="1 - C(12,0)" 	[]
# Attempt text="1 - C(12,0)/C(52,5)" EXCEPTION IN (Eval_parsed.py, LINE 35 "((f,span),op)=e"): need more than 1 value to unpack
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# Attempt text="1 - C(12,0)/C(12,5)" EXCEPTION IN (Eval_parsed.py, LINE 35 "((f,span),op)=e"): need more than 1 value to unpack
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# Attempt text="1 - C(12,0)/C(42,5)" EXCEPTION IN (Eval_parsed.py, LINE 35 "((f,span),op)=e"): need more than 1 value to unpack
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# Attempt text="1 - C(12,0)/C(40,5)" EXCEPTION IN (Eval_parsed.py, LINE 35 "((f,span),op)=e"): need more than 1 value to unpack
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# Attempt text="C(52,5) - C(12,0)" 	[ 5]
# Attempt text="C(40,5) - C(12,0)" 	[ 5]
# Attempt text="C(52,5) - C(12,0)" 	[ 5]
# Attempt text="1 -C(40,5)" 	[ 5]
# Attempt text="C(52,5) - C(40,5)" 	[ 5]
# Attempt text="(C(52,5) - C(40,5)) -(C(52,5) - C(28,5))" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('-', (1, 17)), 'in', ((('-', (1, 17)), (0, 18)), (('C', (1, 7)), 52, 5), (('C', (11, 17)), 40, 5)))
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# Attempt text="C(52,5) - C(40,5) - C(28,5)" 	[ 5]
# Attempt text="C(52,5) - C(40,5) - C(32,5)" 	[ 5,32,201376]
# Attempt text="C(52,5) - C(40,5) * C(32,5)" 	[ 5,32,201376]
# Attempt text="C(52,5) - C(40,5) + C(32,5)" 	[ 5,32,201376]
# Attempt text="C(52,5) - C(40,5) - C(32,5)" 	[ 5,32,201376]
# Attempt text="C(52,5) - C(40,5) - C(20,5)" 	[ 5,20,15504]
# Attempt text="(40,5) - C(20,5)" EXCEPTION IN (Eval_parsed.py, LINE 64 "raise Exception('Unrecognized expression form:',e)"): ('Unrecognized expression form:', (40,))
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 37 "v=get_number(ev)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 37 "v=get_number(ev)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# Attempt text="C(40,5) - C(20,5)" 	[ 5,20,15504]
# Attempt text="C(52,5) - C(40,5) - C(20,5)" 	[ 5,20,15504]
# Attempt text="C(52,5) - C(40,5) - C(20,5) - C(20,4) - C(20,3) - C(20,2) - C(20,1) -C(20,0)" 	[ 4, 5,20,15504]
# Attempt text="C(52,5) - C(40,5) - C(20,5)" 	[ 5,20,15504]
# Attempt text="C(52,5) - C(40,5) - C(20,5) - C(20,4) - C(20,3) - C(20,2) - C(20,1)" 	[ 4, 5,20,15504]
# Attempt text="C(52,5) - C(40,5) - C(52,5) C(20,5) - C(20,4) - C(20,3) - C(20,2) - C(20,1)" 	[ 4, 5,20,15504]
# Attempt text="C(52,5) - C(40,5) - C(52,5) - C(20,5) - C(20,4) - C(20,3) - C(20,2) - C(20,1)" 	[ 4, 5,20,15504]
# Attempt text="C(52,5) - C(40,5) - C(20,5)" 	[ 5,20,15504]
# Attempt text="C(52,5) - C(40,5) - C(32,5)" 	[ 5,32,201376]
# Attempt text="C(52,5) - C(40,5) - C(20,5)"
# 	[ 5,20,15504]
# Attempt text="C(52,5) - C(40,5) *C(20,5)" 	[ 5,20,15504]
# Attempt text="C(52,5) - C(20,5) - C(20,4) - C(20,3) - C(20,2) - C(20,1)" 	[ 4, 5,20,15504]
# Attempt text="C(52,5) - C(20,5) - C(20,4) - C(20,3) - C(20,2) - C(20,1) - C(40,5)" 	[ 4, 5,20,15504]
# Attempt text="C(52,5) - (C(20,5) + C(20,4) + C(20,3) + C(20,2) + C(20,1)) - C(40,5)" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('+', (11, 57)), 'in', ((('+', (11, 57)), (10, 58)), (('+', (11, 47)), (('+', (11, 37)), (('+', (11, 27)), (('C', (11, 17)), 20, 5), (('C', (21, 27)), 20, 4)), (('C', (31, 37)), 20, 3)), (('C', (41, 47)), 20, 2)), (('C', (51, 57)), 20, 1)))
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# Attempt text="C(52,5) - (C(20,5) + C(20,4) + C(20,3) + C(20,2) + C(20,1) + C(20,0)) - C(40,5)" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('+', (11, 67)), 'in', ((('+', (11, 67)), (10, 68)), (('+', (11, 57)), (('+', (11, 47)), (('+', (11, 37)), (('+', (11, 27)), (('C', (11, 17)), 20, 5), (('C', (21, 27)), 20, 4)), (('C', (31, 37)), 20, 3)), (('C', (41, 47)), 20, 2)), (('C', (51, 57)), 20, 1)), (('C', (61, 67)), 20, 0)))
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# Attempt text="C(52,5) - (C(20,5) + C(20,4) + C(20,3) + C(20,2) + C(20,1)) - C(40,5)" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('+', (11, 57)), 'in', ((('+', (11, 57)), (10, 58)), (('+', (11, 47)), (('+', (11, 37)), (('+', (11, 27)), (('C', (11, 17)), 20, 5), (('C', (21, 27)), 20, 4)), (('C', (31, 37)), 20, 3)), (('C', (41, 47)), 20, 2)), (('C', (51, 57)), 20, 1)))
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# Attempt text="C(52,5) - (C(20,5) * C(20,4) * C(20,3) * C(20,2) * C(20,1)) - C(40,5)" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('*', (11, 57)), 'in', ((('*', (11, 57)), (10, 58)), (('*', (11, 47)), (('*', (11, 37)), (('*', (11, 27)), (('C', (11, 17)), 20, 5), (('C', (21, 27)), 20, 4)), (('C', (31, 37)), 20, 3)), (('C', (41, 47)), 20, 2)), (('C', (51, 57)), 20, 1)))
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# Attempt text="C(52,5) - (C(20,5) + C(20,4) + C(20,3) + C(20,2) + C(20,1)) - C(40,5)" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('+', (11, 57)), 'in', ((('+', (11, 57)), (10, 58)), (('+', (11, 47)), (('+', (11, 37)), (('+', (11, 27)), (('C', (11, 17)), 20, 5), (('C', (21, 27)), 20, 4)), (('C', (31, 37)), 20, 3)), (('C', (41, 47)), 20, 2)), (('C', (51, 57)), 20, 1)))
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# Attempt text="C(52,5) - C(36,5)" 	[ 5]
# Attempt text="C(52,5) - (C(20,5) + C(20,4) + C(20,3) + C(20,2) + C(20,1)) - C(40,5)" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('+', (11, 57)), 'in', ((('+', (11, 57)), (10, 58)), (('+', (11, 47)), (('+', (11, 37)), (('+', (11, 27)), (('C', (11, 17)), 20, 5), (('C', (21, 27)), 20, 4)), (('C', (31, 37)), 20, 3)), (('C', (41, 47)), 20, 2)), (('C', (51, 57)), 20, 1)))
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# Attempt text="(C(52,5) - C(20,5) + C(20,4) + C(20,3) + C(20,2) + C(20,1)) - (C(52,5) - C(40,5))" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('+', (1, 57)), 'in', ((('+', (1, 57)), (0, 58)), (('+', (1, 47)), (('+', (1, 37)), (('+', (1, 27)), (('-', (1, 17)), (('C', (1, 7)), 52, 5), (('C', (11, 17)), 20, 5)), (('C', (21, 27)), 20, 4)), (('C', (31, 37)), 20, 3)), (('C', (41, 47)), 20, 2)), (('C', (51, 57)), 20, 1)))
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# Attempt text="C(52,5) - (C(52,5) - C(20,5) + C(20,4) + C(20,3) + C(20,2) + C(20,1)) - (C(52,5) - C(40,5))" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('+', (11, 67)), 'in', ((('+', (11, 67)), (10, 68)), (('+', (11, 57)), (('+', (11, 47)), (('+', (11, 37)), (('-', (11, 27)), (('C', (11, 17)), 52, 5), (('C', (21, 27)), 20, 5)), (('C', (31, 37)), 20, 4)), (('C', (41, 47)), 20, 3)), (('C', (51, 57)), 20, 2)), (('C', (61, 67)), 20, 1)))
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# Attempt text="(C(52,5) - C(20,5) + C(20,4) + C(20,3) + C(20,2) + C(20,1)) - (C(52,5) - C(40,5))" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('+', (1, 57)), 'in', ((('+', (1, 57)), (0, 58)), (('+', (1, 47)), (('+', (1, 37)), (('+', (1, 27)), (('-', (1, 17)), (('C', (1, 7)), 52, 5), (('C', (11, 17)), 20, 5)), (('C', (21, 27)), 20, 4)), (('C', (31, 37)), 20, 3)), (('C', (41, 47)), 20, 2)), (('C', (51, 57)), 20, 1)))
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# Attempt text="(C(52,5) - C(20,5) - C(20,4) - C(20,3) - C(20,2) - C(20,1)) - (C(52,5) - C(40,5))" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('-', (1, 57)), 'in', ((('-', (1, 57)), (0, 58)), (('-', (1, 47)), (('-', (1, 37)), (('-', (1, 27)), (('-', (1, 17)), (('C', (1, 7)), 52, 5), (('C', (11, 17)), 20, 5)), (('C', (21, 27)), 20, 4)), (('C', (31, 37)), 20, 3)), (('C', (41, 47)), 20, 2)), (('C', (51, 57)), 20, 1)))
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# Attempt text="C(52,5) - (C(52,5) - C(20,5) - C(20,4) - C(20,3) - C(20,2) - C(20,1)) - (C(52,5) - C(40,5))" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('-', (11, 67)), 'in', ((('-', (11, 67)), (10, 68)), (('-', (11, 57)), (('-', (11, 47)), (('-', (11, 37)), (('-', (11, 27)), (('C', (11, 17)), 52, 5), (('C', (21, 27)), 20, 5)), (('C', (31, 37)), 20, 4)), (('C', (41, 47)), 20, 3)), (('C', (51, 57)), 20, 2)), (('C', (61, 67)), 20, 1)))
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# Attempt text="C(32,5) + C(32,4) + C(32,3) + C(32,2) + C(32,1) - (C(52,5) - C(40,5))" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('-', (51, 67)), 'in', ((('-', (51, 67)), (50, 68)), (('C', (51, 57)), 52, 5), (('C', (61, 67)), 40, 5)))
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# Attempt text="C(32,5) + C(32,4) + C(32,3) + C(32,2) + C(32,1) + (C(52,5) - C(40,5))" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('-', (51, 67)), 'in', ((('-', (51, 67)), (50, 68)), (('C', (51, 57)), 52, 5), (('C', (61, 67)), 40, 5)))
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# Attempt text="C(52,5) - C(40,5) - C(20,5) - C(20,4) - C(20,3) - C(20,2) - C(20,1)" 	[ 4, 5,20,15504]
# Attempt text="C(52,5) - C(40,5) - (C(20,5) - C(20,4) - C(20,3) - C(20,2) - C(20,1))" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('-', (21, 67)), 'in', ((('-', (21, 67)), (20, 68)), (('-', (21, 57)), (('-', (21, 47)), (('-', (21, 37)), (('C', (21, 27)), 20, 5), (('C', (31, 37)), 20, 4)), (('C', (41, 47)), 20, 3)), (('C', (51, 57)), 20, 2)), (('C', (61, 67)), 20, 1)))
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# Attempt text="(C(20,5) + C(20,4) + C(20,3) + C(20,2) + C(20,1)) - C(52,5) - C(40,5)"
# ERROR:root:Error  : expression . LexToken(VARIABLE,'E',1,17)
# EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('+', (1, 47)), 'in', ((('+', (1, 47)), (0, 48)), (('+', (1, 37)), (('+', (1, 27)), (('+', (1, 17)), (('C', (1, 7)), 20, 5), (('C', (11, 17)), 20, 4)), (('C', (21, 27)), 20, 3)), (('C', (31, 37)), 20, 2)), (('C', (41, 47)), 20, 1)))
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# Attempt text="(C(20,5) + C(20,4) + C(20,3) + C(20,2) + C(20,1)) - C(40,5)" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('+', (1, 47)), 'in', ((('+', (1, 47)), (0, 48)), (('+', (1, 37)), (('+', (1, 27)), (('+', (1, 17)), (('C', (1, 7)), 20, 5), (('C', (11, 17)), 20, 4)), (('C', (21, 27)), 20, 3)), (('C', (31, 37)), 20, 2)), (('C', (41, 47)), 20, 1)))
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# Attempt text="((C(20,5) + C(20,4) + C(20,3) + C(20,2) + C(20,1)) )" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', (('+', (2, 48)), (1, 49)), 'in', (((('+', (2, 48)), (1, 49)), (0, 51)), (('+', (2, 38)), (('+', (2, 28)), (('+', (2, 18)), (('C', (2, 8)), 20, 5), (('C', (12, 18)), 20, 4)), (('C', (22, 28)), 20, 3)), (('C', (32, 38)), 20, 2)), (('C', (42, 48)), 20, 1)))
# Attempt text="C(52,5) - C(40,5) - ((C(20,5) + C(20,4) + C(20,3) + C(20,2) + C(20,1)) )" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', (('+', (22, 68)), (21, 69)), 'in', (((('+', (22, 68)), (21, 69)), (20, 71)), (('+', (22, 58)), (('+', (22, 48)), (('+', (22, 38)), (('C', (22, 28)), 20, 5), (('C', (32, 38)), 20, 4)), (('C', (42, 48)), 20, 3)), (('C', (52, 58)), 20, 2)), (('C', (62, 68)), 20, 1)))
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# Attempt text="12" 	[]
# Attempt text="0" 	[]
# Attempt text="C(20,0)" 	[20]
# Attempt text="C(52,5) - C(40,5) - C(20,0)" 	[ 5,20]
# Attempt text="C(52,5) - C(40,5) + C(20,0)" 	[ 5,20]
# Attempt text="C(52,5) - C(40,5) - C(32,5)" 	[ 5,32,201376]
# Attempt text="C(52,5) - C(40,5) + C(32,5)" 	[ 5,32,201376]
# Attempt text="(C(52,5) - C(40,5)) * C(32,5)" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('-', (1, 17)), 'in', ((('-', (1, 17)), (0, 18)), (('C', (1, 7)), 52, 5), (('C', (11, 17)), 40, 5)))
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# Attempt text="(C(52,5) - C(40,5)) / C(32,5)" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('-', (1, 17)), 'in', ((('-', (1, 17)), (0, 18)), (('C', (1, 7)), 52, 5), (('C', (11, 17)), 40, 5)))
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# Attempt text="(C(52,5) - C(40,5)) * C(32,5)" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('-', (1, 17)), 'in', ((('-', (1, 17)), (0, 18)), (('C', (1, 7)), 52, 5), (('C', (11, 17)), 40, 5)))
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# Attempt text="C(32,5) - (C(52,5) - C(40,5))" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('-', (11, 27)), 'in', ((('-', (11, 27)), (10, 28)), (('C', (11, 17)), 52, 5), (('C', (21, 27)), 40, 5)))
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# Attempt text="C(52,5) - C(40,5) - C(32,5)" 	[ 5,32,201376]
# Attempt text="(C(52,5) - C(40,5)) ^C(32,5)" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('-', (1, 17)), 'in', ((('-', (1, 17)), (0, 18)), (('C', (1, 7)), 52, 5), (('C', (11, 17)), 40, 5)))
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# Attempt text="(C(52,5) - C(40,5)) + C(32,5)" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('-', (1, 17)), 'in', ((('-', (1, 17)), (0, 18)), (('C', (1, 7)), 52, 5), (('C', (11, 17)), 40, 5)))
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# Attempt text="(C(52,5) - C(40,5)) +  C(32,5)" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('-', (1, 17)), 'in', ((('-', (1, 17)), (0, 18)), (('C', (1, 7)), 52, 5), (('C', (11, 17)), 40, 5)))
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# Attempt text="(C(52,5) - C(40,5)) + C(32,5) - (C(32,5)*(C(52,5)-C(40,5)))" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('-', (1, 17)), 'in', ((('-', (1, 17)), (0, 18)), (('C', (1, 7)), 52, 5), (('C', (11, 17)), 40, 5)))
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# Attempt text="(C(52,5) - C(40,5)) + C(32,5) - (C(32,5)+(C(52,5)-C(40,5)))" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('-', (1, 17)), 'in', ((('-', (1, 17)), (0, 18)), (('C', (1, 7)), 52, 5), (('C', (11, 17)), 40, 5)))
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# Attempt text="(C(32,5)+(C(52,5)-C(40,5))) - ((C(52,5) - C(40,5)) + C(32,5))" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('-', (10, 24)), 'in', ((('-', (10, 24)), (9, 25)), (('C', (10, 16)), 52, 5), (('C', (18, 24)), 40, 5)))
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# Attempt text="(C(32,5)+(C(52,5)-C(40,5))) - (C(52,5) - C(40,5)) + C(32,5)" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('-', (10, 24)), 'in', ((('-', (10, 24)), (9, 25)), (('C', (10, 16)), 52, 5), (('C', (18, 24)), 40, 5)))
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# Attempt text="(C(52,5) - C(40,5)) + C(32,5)" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('-', (1, 17)), 'in', ((('-', (1, 17)), (0, 18)), (('C', (1, 7)), 52, 5), (('C', (11, 17)), 40, 5)))
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# Attempt text="1.94095E+06 + C(32,5)" EXCEPTION IN (Eval_parsed.py, LINE 64 "raise Exception('Unrecognized expression form:',e)"): ('Unrecognized expression form:', 'E')
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# Attempt text="C(32,5) + 1.94095E+06 - C(32,5) + 1.94095E+06" Attempt text="C(32,5) - C(40,5)" 	[ 5,32,201376]
# Attempt text="C(40,5) - C(32,5)" 	[ 5,32,201376]
# Attempt text="C(32,5)*(C(52,5) - C(40,5))" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('-', (9, 25)), 'in', ((('-', (9, 25)), (8, 26)), (('C', (9, 15)), 52, 5), (('C', (19, 25)), 40, 5)))
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# Attempt text="C(32,5)-(C(52,5) - C(40,5))" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('-', (9, 25)), 'in', ((('-', (9, 25)), (8, 26)), (('C', (9, 15)), 52, 5), (('C', (19, 25)), 40, 5)))
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# Attempt text="(C(52,5) - C(40,5)) - C(32,5)" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('-', (1, 17)), 'in', ((('-', (1, 17)), (0, 18)), (('C', (1, 7)), 52, 5), (('C', (11, 17)), 40, 5)))
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# Attempt text="C(12,4)" 	[ 4]
# Attempt text="C(52,5) - C(40,5) - C(32,5)" 	[ 5,32,201376]
# Attempt text="C(52,5) - C(40,5) + C(32,5) -C(20,5)" 	[ 5,20,32,15504,201376]
# Attempt text="C(52,5) - C(40,5) + C(32,5) -C(16,5)" 	[ 5,32,201376]
# Attempt text="C(52,5) - C(40,5) + C(32,5) -C(20,5)" 	[ 5,20,32,15504,201376]
# Attempt text="C(52,5) - C(40,5) + C(32,5) -C(28,5)" 	[ 5,32,201376]
# Attempt text="C(52,5) - C(40,5) + C(32,5) -C(12,5)" 	[ 5,32,201376]
# Attempt text="C(52,5) - C(40,5) + C(32,5) -C(4,1)" 	[ 4, 5,32,201376]
# Attempt text="C(52,5) - C(40,5)- C(20,5)" 	[ 5,20,15504]
# Attempt text="C(52,5) - C(40,5) - C(32,5)- C(20,5)" 	[ 5,20,32,15504,201376]
# Attempt text="C(52,5) - C(40,5) - C(32,5) - C(20,5)"
# ERROR:root:Error  : expression MINUS LPAREN expression . LexToken(VARIABLE,'E',1,59)
# ERROR:root:Error  : expression MINUS LPAREN factor . $end
# 	[ 5,20,32,15504,201376]
# Attempt text="C(52,5) - C(40,5) + C(32,5) - C(20,5)" 	[ 5,20,32,15504,201376]
# Attempt text="C(52,5) - C(40,5) + C(32,5) - C(20,5) - (1.94095E+06 -  C(32,5))" EXCEPTION IN (Eval_parsed.py, LINE 64 "raise Exception('Unrecognized expression form:',e)"): ('Unrecognized expression form:', 'E')
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# Attempt text="C(52,5) - C(40,5) + C(32,5) - C(20,5) - (1.94095E+06 - C(32,5))" EXCEPTION IN (Eval_parsed.py, LINE 64 "raise Exception('Unrecognized expression form:',e)"): ('Unrecognized expression form:', 'E')
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# Attempt text="C(52,5) - C(40,5) + C(32,5) - C(20,5) - ( C(32,5) - 1.94095E+06)" Attempt text="C(52,5) - C(40,5) + C(32,5) - C(20,5) - (1.94095E+06 - C(20,5))" EXCEPTION IN (Eval_parsed.py, LINE 64 "raise Exception('Unrecognized expression form:',e)"): ('Unrecognized expression form:', 'E')
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# Attempt text="C(52,5) - C(40,5) + C(32,5) - C(20,5) - ((1.94095E+06 - C(20,5))" Attempt text="C(52,5) - C(40,5) + C(32,5) - C(20,5) - (1.94095E+06 - C(28,5))" EXCEPTION IN (Eval_parsed.py, LINE 64 "raise Exception('Unrecognized expression form:',e)"): ('Unrecognized expression form:', 'E')
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# Attempt text="C(52,5) - C(40,5) + C(32,5) - C(20,5) - (1.94095E+06 - C(40,5))" EXCEPTION IN (Eval_parsed.py, LINE 64 "raise Exception('Unrecognized expression form:',e)"): ('Unrecognized expression form:', 'E')
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# Attempt text="C(52,5) - C(40,5) + C(32,5) - C(20,5) - (1.94095E+06 - C(16,5))" EXCEPTION IN (Eval_parsed.py, LINE 64 "raise Exception('Unrecognized expression form:',e)"): ('Unrecognized expression form:', 'E')
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# Attempt text="C(52,5) - C(40,5) + C(32,5) - C(20,5) - (1.94095E+06 - C(24,5))" EXCEPTION IN (Eval_parsed.py, LINE 64 "raise Exception('Unrecognized expression form:',e)"): ('Unrecognized expression form:', 'E')
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# Attempt text="C(52,5) - C(40,5) + C(32,5) - C(20,5) - (1.94095E+06 - C(20,5))" EXCEPTION IN (Eval_parsed.py, LINE 64 "raise Exception('Unrecognized expression form:',e)"): ('Unrecognized expression form:', 'E')
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# Attempt text="C(52,5) - C(40,5) + C(32,5) - C(20,5) - (1.94095E+06 - C(12,5))" EXCEPTION IN (Eval_parsed.py, LINE 64 "raise Exception('Unrecognized expression form:',e)"): ('Unrecognized expression form:', 'E')
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# Attempt text="C(52,5) - C(40,5) + C(32,5) - C(20,5) - (1.94095E+06 - C(32,5))" EXCEPTION IN (Eval_parsed.py, LINE 64 "raise Exception('Unrecognized expression form:',e)"): ('Unrecognized expression form:', 'E')
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# Attempt text="C(52,5) - C(40,5) + C(32,5) - C(20,5) - (C(52,5) - C(40,5) - C(20,5))" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('-', (41, 67)), 'in', ((('-', (41, 67)), (40, 68)), (('-', (41, 57)), (('C', (41, 47)), 52, 5), (('C', (51, 57)), 40, 5)), (('C', (61, 67)), 20, 5)))
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# Attempt text="C(52,5) - C(40,5) + C(32,5) - C(20,5) - (C(52,5) - C(40,5) - C(47,5))" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('-', (41, 67)), 'in', ((('-', (41, 67)), (40, 68)), (('-', (41, 57)), (('C', (41, 47)), 52, 5), (('C', (51, 57)), 40, 5)), (('C', (61, 67)), 47, 5)))
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# Attempt text="C(52,5) - C(40,5) + C(32,5) - C(20,5) - (C(52,5) - C(40,5) - C(15,5))" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('-', (41, 67)), 'in', ((('-', (41, 67)), (40, 68)), (('-', (41, 57)), (('C', (41, 47)), 52, 5), (('C', (51, 57)), 40, 5)), (('C', (61, 67)), 15, 5)))
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# Attempt text="C(52,5) - C(40,5) + C(32,5) - C(20,5) - (C(52,5) - C(40,5) - C(20,5))" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('-', (41, 67)), 'in', ((('-', (41, 67)), (40, 68)), (('-', (41, 57)), (('C', (41, 47)), 52, 5), (('C', (51, 57)), 40, 5)), (('C', (61, 67)), 20, 5)))
# EXCEPTION IN (Eval_parsed.py, LINE 52 "v2=get_number(ev2)"): object of type 'NoneType' has no len()
# Attempt text="[C(52,5) - C(40,5)] + C(32,5) - C(20,5) - [C(52,5) - C(40,5) - C(20,5)]" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('-', (1, 17)), 'in', ((('-', (1, 17)), (0, 18)), (('C', (1, 7)), 52, 5), (('C', (11, 17)), 40, 5)))
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# Attempt text="[C(52,5) - C(40,5)] + C(32,5) - C(20,5) - [C(52,5) - C(40,5) - C(20,5)] - 1" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('-', (1, 17)), 'in', ((('-', (1, 17)), (0, 18)), (('C', (1, 7)), 52, 5), (('C', (11, 17)), 40, 5)))
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# Attempt text="[C(52,5) - C(40,5)] + C(32,5) - C(20,5) - [C(52,5) - C(40,5) - C(20,5)] "
# EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('-', (1, 17)), 'in', ((('-', (1, 17)), (0, 18)), (('C', (1, 7)), 52, 5), (('C', (11, 17)), 40, 5)))
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# Attempt text="[C(52,5) - C(40,5)] + C(32,5) - C(20,5)" EXCEPTION IN (Eval_parsed.py, LINE 61 "raise Exception('unrecognized binary operator',f,'in',e)"): ('unrecognized binary operator', ('-', (1, 17)), 'in', ((('-', (1, 17)), (0, 18)), (('C', (1, 7)), 52, 5), (('C', (11, 17)), 40, 5)))
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# EXCEPTION IN (Eval_parsed.py, LINE 50 "v1=get_number(ev1)"): object of type 'NoneType' has no len()
# Attempt text="C(32,5) - C(20,5)" 	[ 5,20,32,15504,185872,201376]

# %%
string='C(4*8,5)- C(4*5,5)'
A=webwork_parser.parse_webwork(string)
print A
# Out:
# (('-', (0, 17)), (('C', (0, 7)), (('*', (2, 4)), 4, 8), 5), (('C', (10, 17)), (('*', (12, 14)), 4, 5), 5))

# %%
etree=Eval_parsed.eval_parsed(A)
print etree
# Out:
# (('-', 185872L, (0, 17)), (('C', 201376L, (0, 7)), (('*', 32.0, (2, 4)), (4.0,), (8.0,)), (5.0,)), (('C', 15504, (10, 17)), (('*', 20.0, (12, 14)), (4.0,), (5.0,)), (5.0,)))

# %%
HS=Eval_parsed.Collect_numbers(etree)
HS
# Out:
# {4.0: (4.0,),
#  5.0: (5.0,),
#  8.0: (8.0,),
#  20.0: (('*', 20.0, (12, 14)), (4.0,), (5.0,)),
#  32.0: (('*', 32.0, (2, 4)), (4.0,), (8.0,)),
#  15504: (('C', 15504, (10, 17)),
#   (('*', 20.0, (12, 14)), (4.0,), (5.0,)),
#   (5.0,)),
#  185872L: (('-', 185872L, (0, 17)),
#   (('C', 201376L, (0, 7)), (('*', 32.0, (2, 4)), (4.0,), (8.0,)), (5.0,)),
#   (('C', 15504, (10, 17)), (('*', 20.0, (12, 14)), (4.0,), (5.0,)), (5.0,))),
#  201376L: (('C', 201376L, (0, 7)),
#   (('*', 32.0, (2, 4)), (4.0,), (8.0,)),
#   (5.0,))}

# %%
HG=set(sort(HS.keys()))
HG
# Out:
# {4.0, 5.0, 8.0, 20.0, 32.0, 15504.0, 185872.0, 201376.0}

# %%
def is_number(s):
    try:
        float(s)
        return True
    except ValueError:
        return False

# %%
len((float(1),))
# Out:
# 1
